# %%
import pandas as pd
import bcrypt

# %%
prof_data = pd.read_csv("Professors.csv")
student_data = pd.read_csv("Students_TA.csv")

student_data
# Out:
#                  Full Name               Email  Age    Zip       Phone Gender  \
# 0              Alisa Lynch  ally47@nittany.edu   19  62901  1507045398      F
# 1            Alisha Murray  almu46@nittany.edu   21  46376  3852017301      F
# 2              Alice Kiehn  alki89@nittany.edu   20  30529  4651079903      M
# 3        Anastasia Shields  ansh34@nittany.edu   18  72571  1245720203      F
# 4       Alyce Leuschke Jr.  alle64@nittany.edu   21  80104  5672573168      M
# ..                     ...                 ...  ...    ...         ...    ...
# 995        Dr. Elton Green  drel69@nittany.edu   18  71851  8123631542      M
# 996          Florian Mante  flma12@nittany.edu   22  92276  5317437262      F
# 997             Frank Ryan  frry45@nittany.edu   19  46340  7122157384      F
# 998  Dr. Lambert Jaskolski  drla86@nittany.edu   18  81092  7719679541      M
# 999        Darlene Flatley  dafl41@nittany.edu   22  50039  5429668226      M
#
#                 City       State  Password                   Street  ...  \
# 0         Carbondale    Illinois  ixg1libp   78 South Brewery Ave.   ...
# 1          Schneider     Indiana  4eystjwe       639 Princeton Rd.   ...
# 2           Commerce     Georgia  p0ulbn26     8985 Cambridge Ave.   ...
# 3              Rosie    Arkansas  06e84eor             55 Hall St.   ...
# 4        Castle Rock    Colorado  ev4n7hoh    232 W. Homewood Ave.   ...
# ..               ...         ...       ...                      ...  ...
# 995  Mineral Springs    Arkansas  to578yi5     8985 Cambridge Ave.   ...
# 996   Thousand Palms  California  52ibosdi  798 North Euclid Drive   ...
# 997            Hanna     Indiana  hwazzxlh      461 Heather Street   ...
# 998            Wiley    Colorado  jy0in5m2         358 Marvon Ave.   ...
# 999           Bouton        Iowa  fff7sx3o     9408 Anderson Court   ...
#
#      Course 3 Details Course 3 Section Course 3 Section Limit Course 3 HW_No  \
# 0    3 Credit Course.              2.0                     60            1.0
# 1    3 Credit Course.              1.0                     70            1.0
# 2    3 Credit Course.              1.0                     70            1.0
# 3    3 Credit Course.              1.0                     70            1.0
# 4    3 Credit Course.              2.0                     60            1.0
# ..                ...              ...                    ...            ...
# 995  3 Credit Course.              2.0                     60            1.0
# 996  3 Credit Course.              2.0                     60            1.0
# 997  3 Credit Course.              2.0                     60            1.0
# 998  3 Credit Course.              1.0                     70            1.0
# 999  3 Credit Course.              1.0                     70            1.0
#
#                Course 3 HW_Details  Course 3 HW_Grade  Course 3 EXAM_No  \
# 0    Turn in this homework online!               90.0               NaN
# 1    Turn in this homework online!               60.0               1.0
# 2    Turn in this homework online!               74.0               1.0
# 3    Turn in this homework online!               67.0               1.0
# 4    Turn in this homework online!               97.0               1.0
# ..                             ...                ...               ...
# 995  Turn in this homework online!               78.0               1.0
# 996  Turn in this homework online!               69.0               NaN
# 997  Turn in this homework online!               73.0               1.0
# 998  Turn in this homework online!               81.0               1.0
# 999  Turn in this homework online!               63.0               1.0
#
#               Course 3 Exam_Details  Course 3 EXAM_Grade  Teaching Team ID
# 0                               NaN                  NaN               NaN
# 1    Closed book exam for 100 marks                 84.0               NaN
# 2    Closed book exam for 100 marks                 87.0               NaN
# 3    Closed book exam for 100 marks                 95.0               NaN
# 4    Closed book exam for 100 marks                 97.0               NaN
# ..                              ...                  ...               ...
# 995  Closed book exam for 100 marks                 70.0               NaN
# 996                             NaN                  NaN               NaN
# 997  Closed book exam for 100 marks                 68.0               NaN
# 998  Closed book exam for 100 marks                 81.0               NaN
# 999  Closed book exam for 100 marks                 77.0               NaN
#
# [1000 rows x 45 columns]

# %%
prof_data
user_prof = prof_data[["Email", "Password"]]
user_stud = student_data[["Email", "Password"]]
user_data = pd.concat([user_prof, user_stud])
user_data[user_data["Email"] == "dm17@nittany.edu"]
user_data.to_csv("users_not_encrypted.csv", index = False)

# %%
lst = list(user_data["Password"])
for i in range(len(user_data["Password"])):
    user_data["Password"][i] = bcrypt.hashpw(lst[i].encode('utf8'), bcrypt.gensalt(rounds = 10, prefix=b"2a"))

# %%
print(user_data[user_data["Email"] == "dm17@nittany.edu"])
# user_data.to_csv("users.csv", index = False)
# Out:
#                Email                                           Password
# 53  dm17@nittany.edu  b'$2a$10$B0fq4PEJMWokGpIHuu07quhbOmA6xaiFglINS...

# %%
bcrypt.hashpw("jlt1x825".encode('utf8'), bcrypt.gensalt(rounds = 10, prefix=b"2a"))
# Out:
# b'$2a$10$3G.7rfYPnaQx9/L.iIb/r.UacQ0cMJxXRmzJCC19Cm.50qMa.baU6'
